# %% [markdown]
# <a href="https://colab.research.google.com/github/Brainspark1/Continuous-Voice-Learning/blob/main/Audio2Spectrogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa matplotlib soundfile

# %%
# import everything necessary

# audio processing
import librosa
import librosa.feature
import librosa.display

import numpy as np
import matplotlib.pyplot as plt

# %%
audio_path = "example_sound.wav"

# y = waveform, sr = sample rate
waveform, sample_rate = librosa.load(audio_path, sr=16000)

# %%
mel_spec = librosa.feature.melspectrogram(
    y=waveform,
    sr=sample_rate,
    n_fft=1024,
    hop_length=512,
    n_mels=128
)

# %%
# converting to decibels to display in spectrogram

mel_db = librosa.power_to_db(mel_spec, ref=np.max)

# %%
plt.figure(figsize=(10,4))

librosa.display.specshow(
    mel_db,
    sr=sample_rate,
    hop_length=512,
    x_axis="time",
    y_axis="mel"
)

plt.colorbar(format="%+2.0f dB")
plt.title("Mel Spectrogram")
plt.tight_layout()
plt.show()
